# %% [markdown]
# # Phase 1
# You are a Principal Solution Architect specializing in enterprise-scale distributed systems and Microservices architecture.
#
# Your task is to design the HIGH-LEVEL ARCHITECTURE for a production-grade Cinema Management Platform.
#
# IMPORTANT:
# You MUST first perform deep requirement discovery before proposing architecture.
#
# You MUST ask targeted questions regarding:
# - DAU/MAU
# - Peak concurrent booking traffic
# - TPS/RPS expectations
# - Real-time requirements
# - Multi-region requirements
# - SLA/SLO
# - Payment consistency requirements
# - Expected scaling
# - Cloud provider
# - Budget constraints
# - Admin/backoffice complexity
# - Analytics/reporting requirements
# - Security/compliance requirements
# - Monorepo vs Polyrepo preference
#
# After requirements are clarified, generate:
#
# 1. Executive Summary
# 2. Functional Requirements
# 3. Non-Functional Requirements
# 4. Domain-Driven Design (DDD) decomposition
# 5. Bounded Contexts
# 6. Microservices breakdown
# 7. Database-per-service strategy
# 8. Sync vs async communication strategy
# 9. Kafka/RabbitMQ event-driven architecture
# 10. API Gateway architecture
# 11. JWT Authentication/Authorization flow
# 12. High-level caching strategy
# 13. High-level scalability strategy
# 14. Technology stack recommendation
# 15. High-level Mermaid.js architecture diagrams
#
# IMPORTANT:
# - Focus ONLY on high-level architecture.
# - Do NOT deep dive into table schemas or APIs yet.
# - Avoid generic explanations.
# - Explain tradeoffs and architectural decisions.

# %% [markdown]
# # Prompt for next Phase after requirements are clarified:
# <context>
# [PASTE ARCHITECTURE DECISION SUMMARY HERE]
# </context>
#
# <immutable_constraints>
# [PASTE IMMUTABLE CONSTRAINTS HERE]
# </immutable_constraints>
#
# <instructions>
# Treat all previous architecture decisions as finalized constraints unless explicitly revised.
# Maintain strict consistency with the existing architecture.
# Do not redesign previously finalized components unless necessary.
# </instructions>
#
# [PASTE NEXT PHASE PROMPT HERE]

# %% [markdown]
# # Phase 2
# Use the previous architecture decisions as hard constraints unless explicitly revised.
# Maintain consistency with previous phases.
#
# You are now acting as a Principal Backend Architect designing production-grade backend systems for high-concurrency transactional platforms.
#
# Deep dive into the TWO MOST CRITICAL SERVICES:
#
# 1. Booking Service
# 2. Payment Service
#
# The design must assume:
# - very high concurrent seat booking traffic,
# - real-time seat reservation,
# - strict prevention of double booking,
# - distributed systems environment,
# - event-driven architecture.
#
# Generate:
#
# 1. Service Responsibilities
# 2. Internal Module Design
# 3. Database Schema Design
#    - SQL DDL
#    - indexes
#    - constraints
#    - partitioning considerations
#
# 4. Redis Strategy
#    - seat locking
#    - TTL
#    - distributed locking
#    - race condition prevention
#
# 5. API Design
#    Include:
#    - REST endpoints
#    - request/response payloads
#    - validation strategy
#    - pagination/filtering
#    - idempotency keys
#    - error handling
#    - rate limiting
#
# 6. Security Design
#    Include:
#    - JWT validation
#    - RBAC
#    - payment security
#    - PCI-related considerations
#
# 7. Event Design
#    Include:
#    - Kafka topics
#    - event contracts
#    - retry strategy
#    - DLQ strategy
#
# 8. Distributed Transaction Design
#    Include:
#    - Saga pattern
#    - Outbox pattern
#    - compensation handling
#    - eventual consistency handling
#
# 9. Mermaid.js sequence diagrams for:
#    - booking workflow
#    - payment workflow
#    - booking cancellation workflow
#
# 10. Failure scenarios and resiliency handling
#
# IMPORTANT:
# Focus heavily on concurrency control, consistency, idempotency, and fault tolerance.

# %% [markdown]
# # Phase 3
# Use the previous architecture decisions as hard constraints unless explicitly revised.
# Maintain consistency with previous phases.
#
# You are now acting as a Distributed Systems Architect reviewing the event-driven architecture of the Cinema Management Platform.
#
# Deeply analyze and improve:
#
# 1. Kafka/RabbitMQ architecture
# 2. Event contracts
# 3. Event versioning strategy
# 4. Ordering guarantees
# 5. Exactly-once vs at-least-once tradeoffs
# 6. Idempotent consumer strategy
# 7. Retry architecture
# 8. Dead-letter queue design
# 9. Outbox pattern implementation
# 10. Saga orchestration vs choreography
# 11. Distributed tracing strategy
# 12. Service resiliency
# 13. Circuit breaker strategy
# 14. Backpressure handling
# 15. Cache consistency strategy
#
# Generate:
# - detailed event flow diagrams,
# - retry sequence diagrams,
# - failure recovery scenarios,
# - operational bottleneck analysis,
# - scalability bottleneck analysis.
#
# IMPORTANT:
# Avoid textbook explanations.
# Focus on production-scale distributed systems concerns.

# %% [markdown]
# # Phase 4
# Use the previous architecture decisions as hard constraints unless explicitly revised.
# Maintain consistency with previous phases.
#
# You are now acting as a Staff Frontend Architect specializing in large-scale ReactJS monorepo systems.
#
# Design the FRONTEND ARCHITECTURE and MONOREPO STRATEGY for the Cinema Management Platform.
#
# Generate:
#
# 1. Monorepo Strategy
#    Include:
#    - Nx vs Turborepo tradeoff analysis
#    - workspace structure
#    - shared libraries
#    - shared types/contracts
#    - dependency graph strategy
#    - incremental builds
#    - affected-service detection
#
# 2. Repository Tree Structure
#    Include:
#    - apps/
#    - packages/
#    - shared/
#    - ui/
#    - config/
#    - infra/
#
# 3. Frontend Architecture
#    Include:
#    - feature-based folder structure
#    - routing architecture
#    - layout system
#    - authentication flow
#    - protected routes
#    - lazy loading/code splitting
#    - error boundaries
#    - API layer architecture
#
# 4. State Management
#    Compare:
#    - Redux Toolkit
#    - Zustand
#    - React Query/TanStack Query
#
# Explain:
# - what should be global state,
# - what should be server state,
# - what should be local state.
#
# 5. Axios Interceptor Design
#    Include:
#    - JWT injection
#    - refresh token flow
#    - token rotation
#    - retry handling
#    - logout handling
#
# 6. Real-Time Seat Selection Design
#    Include:
#    - WebSocket architecture
#    - optimistic updates
#    - synchronization strategy
#    - seat conflict handling
#
# 7. Ant Design Component Strategy
#    Include:
#    - seat selection UI
#    - booking flow
#    - admin dashboard
#    - analytics dashboard
#    - forms/tables/charts
#
# 8. Frontend Performance Optimization
#    Include:
#    - virtualization
#    - memoization
#    - bundle splitting
#    - CDN strategy
#
# Generate Mermaid diagrams where useful.

# %% [markdown]
# # Phase 5
# Use the previous architecture decisions as hard constraints unless explicitly revised.
# Maintain consistency with previous phases.
#
# You are now acting as a Principal DevOps and Platform Engineer.
#
# Design the LOCAL DEVELOPMENT and KUBERNETES INFRASTRUCTURE for the Cinema Management Platform.
#
# Generate ACTUAL CONFIGURATION FILES where applicable.
#
# Include:
#
# 1. docker-compose.yml
#    Include:
#    - PostgreSQL
#    - MongoDB
#    - Redis
#    - Kafka/RabbitMQ
#    - Zookeeper (if needed)
#    - API Gateway
#    - core services
#
# 2. Kubernetes Architecture
#    Include:
#    - namespace strategy
#    - ingress architecture
#    - service discovery
#    - autoscaling
#    - config management
#
# 3. Generate ACTUAL YAML manifests:
#    - Deployment
#    - Service
#    - Ingress
#    - ConfigMap
#    - Secret
#    - HPA
#
# 4. Minikube vs Kind tradeoff analysis
#
# 5. Secret Management Strategy
#
# 6. Infrastructure as Code recommendations
#
# 7. Containerization best practices
#
# 8. Resource limit recommendations
#
# 9. Local developer experience optimization
#
# 10. Production deployment considerations
#
# IMPORTANT:
# Provide production-grade DevOps reasoning, not tutorial-level explanations.

# %% [markdown]
# # Phase 6
# Use the previous architecture decisions as hard constraints unless explicitly revised.
# Maintain consistency with previous phases.
#
# You are now acting as a Principal DevOps Architect specializing in enterprise CI/CD and GitOps systems.
#
# Design a SMART MONOREPO CI/CD PIPELINE for the Cinema Management Platform.
#
# The pipeline MUST optimize builds and deployments by only processing affected services.
#
# Generate:
#
# 1. CI/CD Architecture
# 2. GitHub Actions or GitLab CI design
# 3. Affected-service detection strategy
# 4. Dependency graph analysis
# 5. Incremental builds
# 6. Parallel execution strategy
# 7. Docker layer caching strategy
# 8. Test strategy
# 9. SonarQube integration
# 10. Security scanning
# 11. Docker build & push workflow
# 12. GitOps workflow
# 13. ArgoCD integration
# 14. Rolling deployment strategy
# 15. Blue/Green vs Canary deployment analysis
# 16. Rollback strategy
# 17. Preview environments
# 18. Artifact management
# 19. Branching strategy
# 20. Release strategy
#
# Generate:
# - actual CI/CD YAML examples,
# - GitHub Actions workflows,
# - deployment flow diagrams,
# - GitOps repository structure.
#
# IMPORTANT:
# Focus on enterprise-scale monorepo optimization and deployment efficiency.

# %% [markdown]
# # Phase 7
# Use all previous architecture decisions as hard constraints unless explicitly revised.
#
# You are now acting as a highly critical CTO conducting a FINAL PRODUCTION READINESS REVIEW.
#
# Review the ENTIRE Cinema Management Platform architecture from all previous phases.
#
# Identify:
# - scalability bottlenecks,
# - reliability risks,
# - operational risks,
# - security weaknesses,
# - data consistency risks,
# - team scalability concerns,
# - DevOps complexity,
# - cost inefficiencies,
# - maintainability issues,
# - disaster recovery weaknesses.
#
# Then:
# 1. Score the entire system out of 100
# 2. Explain ALL deductions
# 3. Recommend improvements
# 4. Identify future scalability roadmap
# 5. Recommend production hardening improvements
#
# IMPORTANT:
# Be extremely critical and realistic.
# Avoid generic praise.
# Think like a CTO reviewing a system before approving production launch.
